# %%
#problem 1
THICKNESS = 0.00008
folded_thickness = THICKNESS * pow(2,43)
print("Thickness: {} meters".format(folded_thickness))
# Out:
# Thickness: 703687441.77664 meters

# %%
#problem 2
print("Thickness: {:.2f}*10^4 kilometers".format(folded_thickness/(10000*1000)))
# Out:
# Thickness: 70.37*10^4 kilometers

# %%
#problem 3
p = 1
for i in range(43):
    p = p * 2

# %%
#problem 4
import time
import timeit
start = time.time()
p = 1
for i in range(43):
    p = p * 2
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 0.0010352134704589844[s]

# %%
# %%timeit
#problem 4
p = 1
for i in range(43):
    p = p * 2
# Out:
# 1.63 µs ± 93.3 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
#problem 5
thicknessList = [THICKNESS]
for i in range(43):
    thicknessList.append(thicknessList[i]*2)
print(len(thicknessList))
# Out:
# 44

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.plot(thicknessList) # Enter the variable name of the list in "List name"
plt.show()

# %%
#problem 7
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # Make settings related to axis values
plt.plot(thicknessList, color = 'green', linewidth = 2) # Enter the variable name of the list in "List name"
plt.show()

# %%
#problem 7
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # Make settings related to axis values
plt.plot(thicknessList, color = 'red', marker = '*', mec = 'blue') # Enter the variable name of the list in "List name"
plt.show()

# %%
#problem 7
import matplotlib.pyplot as plt
# %matplotlib inline
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # Make settings related to axis values
plt.plot(thicknessList, color = 'black', linestyle = 'dashed', linewidth = 3) # Enter the variable name of the list in "List name"
plt.show()
